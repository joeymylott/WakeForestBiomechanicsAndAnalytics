# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Download excel files and combine Data Frames

wakedf = pd.read_csv(r'C:\Users\joeym\Documents\Wake Forest\Pitching Lab\WakePitchersAsOfJan2021.csv')
#rightydf = pd.read_csv(r'C:\Users\joeym\Documents\Wake Forest\Baseball Analytics\Team Biomechanics\wakeRHpitchers.csv')

#dfs = [leftydf, rightydf]

#wakedf = pd.concat(dfs, axis=0,ignore_index=True)
wakedf
# Out:
#            Unnamed: 0              Unnamed: 1 Lead_Knee_Ang_Vel_Max  \
# 0                 NaN                     NaN                METRIC
# 1                 NaN                     NaN             PROCESSED
# 2                 NaN                     NaN                     X
# 3    Antonio Menendez  Breaking Ball RH 1.c3d            447.417145
# 4    Antonio Menendez  Breaking Ball RH 2.c3d            442.906586
# ..                ...                     ...                   ...
# 369      Will Andrews      Off Speed RH 3.c3d            425.348267
# 370      Will Fleming  Breaking Ball RH 1.c3d             476.96637
# 371      Will Fleming       Fastball RH 2.c3d             472.78009
# 372      Will Fleming       Fastball RH 3.c3d            491.521118
# 373      Will Fleming       Fastball RH 4.c3d            479.761627
#
#     Lead_Knee_Ang_Vel_Max.1 Lead_Knee_Ang_Vel_Max.2 Back_Leg_GRF_mag_max  \
# 0                    METRIC                  METRIC               METRIC
# 1                 PROCESSED               PROCESSED            PROCESSED
# 2                         Y                       Z                    X
# 3                115.749641              360.118927             1.699206
# 4                139.731674               324.02356              1.58675
# ..                      ...                     ...                  ...
# 369               210.92865              285.726746             1.689309
# 370              145.885223              267.351135             1.732077
# 371              124.608902              305.572144             1.884336
# 372               168.14621              239.631256             1.950241
# 373              141.261108              277.333923              1.90766
#
#     Hip Shoulders Sep@Footstrike Hip Shoulders Sep@Footstrike.1  \
# 0                         METRIC                         METRIC
# 1                      PROCESSED                      PROCESSED
# 2                              X                              Y
# 3                      25.344067                       7.582581
# 4                       7.837628                     -12.884592
# ..                           ...                            ...
# 369                    12.767086                       4.536453
# 370                    12.781916                      -0.655268
# 371                    13.166245                      -4.100532
# 372                      8.84278                      -3.583838
# 373                    12.908309                      -1.556703
#
#     Hip Shoulders Sep@Footstrike.2 Lead_Knee_Angle@Footstrike  ...  \
# 0                           METRIC                     METRIC  ...
# 1                        PROCESSED                  PROCESSED  ...
# 2                                Z                          X  ...
# 3                        37.648571                  29.001602  ...
# 4                         44.36829                  42.986298  ...
# ..                             ...                        ...  ...
# 369                      63.951683                  46.942848  ...
# 370                      31.712303                  48.794037  ...
# 371                       34.29747                  51.383347  ...
# 372                       35.14053                  51.705925  ...
# 373                      36.759022                  50.475491  ...
#
#     Max_Shoulder_Hor_Abd_Torque.1 Max_Shoulder_Hor_Add_Torque  \
# 0                     EVENT_LABEL                 EVENT_LABEL
# 1                        ORIGINAL                    ORIGINAL
# 2                               X                           X
# 3                             NaN                       2.372
# 4                             NaN                       1.568
# ..                            ...                         ...
# 369                           NaN                     3.69667
# 370                         2.032                         NaN
# 371                          1.56                         NaN
# 372                          2.54                         NaN
# 373                         2.788                         NaN
#
#     Elbow_Torque@Max_Shoulder_Rot Elbow_Torque@Release  \
# 0                          METRIC               METRIC
# 1                       PROCESSED            PROCESSED
# 2                               X                    X
# 3                        -0.00312             -0.01741
# 4                         0.00041             -0.02035
# ..                            ...                  ...
# 369                       0.01147             -0.01325
# 370                           NaN                  NaN
# 371                           NaN                  NaN
# 372                           NaN                  NaN
# 373                           NaN                  NaN
#
#     Pitching_Elbow_Angle@Release Pitching_Elbow_Angle@Release.1  \
# 0                         METRIC                         METRIC
# 1                      PROCESSED                      PROCESSED
# 2                              X                              Y
# 3                       17.77682                       -3.52921
# 4                       14.81031                       -4.94527
# ..                           ...                            ...
# 369                     25.91226                       21.41368
# 370                     16.08992                       -7.03863
# 371                     14.95552                       -4.74176
# 372                     16.00492                       -4.66646
# 373                     15.46125                       -4.38598
#
#     Pitching_Elbow_Angle@Release.2 Pitching_Elbow_Angle_max  \
# 0                           METRIC                   METRIC
# 1                        PROCESSED                PROCESSED
# 2                                Z                        X
# 3                        -69.57805                109.66978
# 4                        -65.53112                118.38982
# ..                             ...                      ...
# 369                      -52.75742                 120.5332
# 370                       77.15968                 83.37768
# 371                       84.83462                 88.69725
# 372                       83.89753                 90.32365
# 373                        84.0318                 93.13942
#
#     Pitching_Elbow_Angle_max.1 Pitching_Elbow_Angle_max.2
# 0                       METRIC                     METRIC
# 1                    PROCESSED                  PROCESSED
# 2                            Y                          Z
# 3                     15.62593                  -41.75812
# 4                     16.82565                  -33.91401
# ..                         ...                        ...
# 369                   30.77501                  -30.20061
# 370                    0.49597                   83.23711
# 371                    3.70082                  109.74193
# 372                    3.53192                  118.78202
# 373                    0.21685                  107.82488
#
# [374 rows x 97 columns]

# %%
# Delete useless rows

WFdf = wakedf.drop([0, 1, 2])
WFdf

# Rename Unnamed columns

WFdf.rename(columns = {'Unnamed: 0':'Pitcher'}, inplace = True) 
WFdf.rename(columns = {'Unnamed: 1':'PitchType'}, inplace = True) 
WFdf
# Out:
#               Pitcher               PitchType Lead_Knee_Ang_Vel_Max  \
# 3    Antonio Menendez  Breaking Ball RH 1.c3d            447.417145
# 4    Antonio Menendez  Breaking Ball RH 2.c3d            442.906586
# 5    Antonio Menendez       Fastball RH 1.c3d            418.166321
# 6    Antonio Menendez       Fastball RH 2.c3d            416.739197
# 7    Antonio Menendez       Fastball RH 3.c3d            463.277435
# ..                ...                     ...                   ...
# 369      Will Andrews      Off Speed RH 3.c3d            425.348267
# 370      Will Fleming  Breaking Ball RH 1.c3d             476.96637
# 371      Will Fleming       Fastball RH 2.c3d             472.78009
# 372      Will Fleming       Fastball RH 3.c3d            491.521118
# 373      Will Fleming       Fastball RH 4.c3d            479.761627
#
#     Lead_Knee_Ang_Vel_Max.1 Lead_Knee_Ang_Vel_Max.2 Back_Leg_GRF_mag_max  \
# 3                115.749641              360.118927             1.699206
# 4                139.731674               324.02356              1.58675
# 5                129.898682               315.67627             1.762823
# 6                128.615387              312.474976             1.650237
# 7                106.045303              405.940674             1.695989
# ..                      ...                     ...                  ...
# 369               210.92865              285.726746             1.689309
# 370              145.885223              267.351135             1.732077
# 371              124.608902              305.572144             1.884336
# 372               168.14621              239.631256             1.950241
# 373              141.261108              277.333923              1.90766
#
#     Hip Shoulders Sep@Footstrike Hip Shoulders Sep@Footstrike.1  \
# 3                      25.344067                       7.582581
# 4                       7.837628                     -12.884592
# 5                      24.120113                       0.584901
# 6                      23.981058                       1.614084
# 7                      10.621145                      -7.608779
# ..                           ...                            ...
# 369                    12.767086                       4.536453
# 370                    12.781916                      -0.655268
# 371                    13.166245                      -4.100532
# 372                      8.84278                      -3.583838
# 373                    12.908309                      -1.556703
#
#     Hip Shoulders Sep@Footstrike.2 Lead_Knee_Angle@Footstrike  ...  \
# 3                        37.648571                  29.001602  ...
# 4                         44.36829                  42.986298  ...
# 5                        42.150604                  29.031528  ...
# 6                        43.153107                  31.275621  ...
# 7                        43.985134                  45.006199  ...
# ..                             ...                        ...  ...
# 369                      63.951683                  46.942848  ...
# 370                      31.712303                  48.794037  ...
# 371                       34.29747                  51.383347  ...
# 372                       35.14053                  51.705925  ...
# 373                      36.759022                  50.475491  ...
#
#     Max_Shoulder_Hor_Abd_Torque.1 Max_Shoulder_Hor_Add_Torque  \
# 3                             NaN                       2.372
# 4                             NaN                       1.568
# 5                             NaN                        1.84
# 6                             NaN                       3.252
# 7                             NaN                       3.344
# ..                            ...                         ...
# 369                           NaN                     3.69667
# 370                         2.032                         NaN
# 371                          1.56                         NaN
# 372                          2.54                         NaN
# 373                         2.788                         NaN
#
#     Elbow_Torque@Max_Shoulder_Rot Elbow_Torque@Release  \
# 3                        -0.00312             -0.01741
# 4                         0.00041             -0.02035
# 5                         0.00421             -0.00701
# 6                        -0.00055             -0.02147
# 7                         0.00393             -0.01025
# ..                            ...                  ...
# 369                       0.01147             -0.01325
# 370                           NaN                  NaN
# 371                           NaN                  NaN
# 372                           NaN                  NaN
# 373                           NaN                  NaN
#
#     Pitching_Elbow_Angle@Release Pitching_Elbow_Angle@Release.1  \
# 3                       17.77682                       -3.52921
# 4                       14.81031                       -4.94527
# 5                        8.16356                        0.89832
# 6                       17.69385                       -5.32543
# 7                       14.46912                       -5.32881
# ..                           ...                            ...
# 369                     25.91226                       21.41368
# 370                     16.08992                       -7.03863
# 371                     14.95552                       -4.74176
# 372                     16.00492                       -4.66646
# 373                     15.46125                       -4.38598
#
#     Pitching_Elbow_Angle@Release.2 Pitching_Elbow_Angle_max  \
# 3                        -69.57805                109.66978
# 4                        -65.53112                118.38982
# 5                        -75.91105                114.94846
# 6                        -83.72028                113.73364
# 7                        -90.60345                121.48134
# ..                             ...                      ...
# 369                      -52.75742                 120.5332
# 370                       77.15968                 83.37768
# 371                       84.83462                 88.69725
# 372                       83.89753                 90.32365
# 373                        84.0318                 93.13942
#
#     Pitching_Elbow_Angle_max.1 Pitching_Elbow_Angle_max.2
# 3                     15.62593                  -41.75812
# 4                     16.82565                  -33.91401
# 5                     18.45097                  -54.36364
# 6                     17.98087                  -62.50832
# 7                      18.4576                   -59.8975
# ..                         ...                        ...
# 369                   30.77501                  -30.20061
# 370                    0.49597                   83.23711
# 371                    3.70082                  109.74193
# 372                    3.53192                  118.78202
# 373                    0.21685                  107.82488
#
# [371 rows x 97 columns]

# %%
# Filter out just fastballs

wakefb = WFdf[WFdf['PitchType'].str.contains('Fastball')]
wakefb
# Out:
#               Pitcher          PitchType Lead_Knee_Ang_Vel_Max  \
# 5    Antonio Menendez  Fastball RH 1.c3d            418.166321
# 6    Antonio Menendez  Fastball RH 2.c3d            416.739197
# 7    Antonio Menendez  Fastball RH 3.c3d            463.277435
# 12   Antonio Menendez  Fastball RH 1.c3d            475.484375
# 13   Antonio Menendez  Fastball RH 2.c3d            447.303436
# ..                ...                ...                   ...
# 365      Will Andrews  Fastball RH 2.c3d            468.544006
# 366      Will Andrews  Fastball RH 3.c3d            490.269135
# 371      Will Fleming  Fastball RH 2.c3d             472.78009
# 372      Will Fleming  Fastball RH 3.c3d            491.521118
# 373      Will Fleming  Fastball RH 4.c3d            479.761627
#
#     Lead_Knee_Ang_Vel_Max.1 Lead_Knee_Ang_Vel_Max.2 Back_Leg_GRF_mag_max  \
# 5                129.898682               315.67627             1.762823
# 6                128.615387              312.474976             1.650237
# 7                106.045303              405.940674             1.695989
# 12               137.960449              218.998596             1.678991
# 13               136.876556              232.643463             1.626184
# ..                      ...                     ...                  ...
# 365              114.637657              305.551575             1.573714
# 366              118.045311              323.667267             1.595325
# 371              124.608902              305.572144             1.884336
# 372               168.14621              239.631256             1.950241
# 373              141.261108              277.333923              1.90766
#
#     Hip Shoulders Sep@Footstrike Hip Shoulders Sep@Footstrike.1  \
# 5                      24.120113                       0.584901
# 6                      23.981058                       1.614084
# 7                      10.621145                      -7.608779
# 12                     22.040331                       2.672199
# 13                     19.756073                      -0.077313
# ..                           ...                            ...
# 365                     18.77655                       5.481593
# 366                    22.789043                       7.006543
# 371                    13.166245                      -4.100532
# 372                      8.84278                      -3.583838
# 373                    12.908309                      -1.556703
#
#     Hip Shoulders Sep@Footstrike.2 Lead_Knee_Angle@Footstrike  ...  \
# 5                        42.150604                  29.031528  ...
# 6                        43.153107                  31.275621  ...
# 7                        43.985134                  45.006199  ...
# 12                       49.209362                  33.116295  ...
# 13                       45.027069                  33.889011  ...
# ..                             ...                        ...  ...
# 365                        61.3512                  53.788975  ...
# 366                      58.740433                  57.980034  ...
# 371                       34.29747                  51.383347  ...
# 372                       35.14053                  51.705925  ...
# 373                      36.759022                  50.475491  ...
#
#     Max_Shoulder_Hor_Abd_Torque.1 Max_Shoulder_Hor_Add_Torque  \
# 5                             NaN                        1.84
# 6                             NaN                       3.252
# 7                             NaN                       3.344
# 12                            NaN                       1.928
# 13                            NaN                       1.596
# ..                            ...                         ...
# 365                           NaN                     6.61667
# 366                           NaN                     4.59667
# 371                          1.56                         NaN
# 372                          2.54                         NaN
# 373                         2.788                         NaN
#
#     Elbow_Torque@Max_Shoulder_Rot Elbow_Torque@Release  \
# 5                         0.00421             -0.00701
# 6                        -0.00055             -0.02147
# 7                         0.00393             -0.01025
# 12                        0.00013             -0.01208
# 13                        0.00162             -0.01114
# ..                            ...                  ...
# 365                       0.00854             -0.00468
# 366                       0.00843              0.00928
# 371                           NaN                  NaN
# 372                           NaN                  NaN
# 373                           NaN                  NaN
#
#     Pitching_Elbow_Angle@Release Pitching_Elbow_Angle@Release.1  \
# 5                        8.16356                        0.89832
# 6                       17.69385                       -5.32543
# 7                       14.46912                       -5.32881
# 12                      14.93136                       -4.03465
# 13                      14.14611                       -6.06779
# ..                           ...                            ...
# 365                     26.49893                       12.05446
# 366                     26.19729                       12.00171
# 371                     14.95552                       -4.74176
# 372                     16.00492                       -4.66646
# 373                     15.46125                       -4.38598
#
#     Pitching_Elbow_Angle@Release.2 Pitching_Elbow_Angle_max  \
# 5                        -75.91105                114.94846
# 6                        -83.72028                113.73364
# 7                        -90.60345                121.48134
# 12                       -89.30856                113.25269
# 13                       -94.62462                111.35855
# ..                             ...                      ...
# 365                     -102.55173                127.35921
# 366                     -102.42304                127.61462
# 371                       84.83462                 88.69725
# 372                       83.89753                 90.32365
# 373                        84.0318                 93.13942
#
#     Pitching_Elbow_Angle_max.1 Pitching_Elbow_Angle_max.2
# 5                     18.45097                  -54.36364
# 6                     17.98087                  -62.50832
# 7                      18.4576                   -59.8975
# 12                    16.24556                  -54.43756
# 13                    15.85747                  -57.83587
# ..                         ...                        ...
# 365                   26.89344                  -73.83244
# 366                   26.16654                  -76.19609
# 371                    3.70082                  109.74193
# 372                    3.53192                  118.78202
# 373                    0.21685                  107.82488
#
# [139 rows x 97 columns]

# %%
# Covert columns to floats

wakefb['Pelvis_Ang_Vel_max'] = wakefb['Pelvis_Ang_Vel_max'].astype(float)
wakefb['Thorax_Ang_Vel_max'] = wakefb['Thorax_Ang_Vel_max'].astype(float)
wakefb['Pitching_Humerus_Ang_Vel_max'] = wakefb['Pitching_Humerus_Ang_Vel_max'].astype(float)
wakefb['Pitching_Hand_Ang_Vel_max'] = wakefb['Pitching_Hand_Ang_Vel_max'].astype(float)
wakefb['Pitching_Elbow_Angle@Max_Shoulder_RotX'] = wakefb['Pitching_Elbow_Angle@Max_Shoulder_RotX'].astype(float)
# Out:
# <ipython-input-19-080925922aeb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wakefb['Pelvis_Ang_Vel_max'] = wakefb['Pelvis_Ang_Vel_max'].astype(float)
# <ipython-input-19-080925922aeb>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wakefb['Thorax_Ang_Vel_max'] = wakefb['Thorax_Ang_Vel_max'].astype(float)
# <ipython-input-19-080925922aeb>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wakefb['Pitching_Humerus_Ang_Vel_max'] = wakefb['Pitching_Humerus_Ang_Vel_max'].astype(float)
# <ipython-input-19-080925922aeb>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wakefb['Pitching_Hand_Ang_Vel_max'] = wakefb['Pitching_Hand_Ang_Vel_max'].astype(float)
# <ipython-input-19-080925922aeb>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wakefb['Pitching_Elbow_Angle@Max_Shoulder_RotX'] = wakefb['Pitching_Elbow_Angle@Max_Shoulder_RotX'].astype(float)

# %%
# Pull min and max values from kinematic sequence metrics

pelvismax = wakefb['Pelvis_Ang_Vel_max'].max()
thoraxmax = wakefb['Thorax_Ang_Vel_max'].max()
humerusmax = wakefb['Pitching_Humerus_Ang_Vel_max'].max()
handmax = wakefb['Pitching_Hand_Ang_Vel_max'].max()

pelvismin = wakefb['Pelvis_Ang_Vel_max'].min()
thoraxmin = wakefb['Thorax_Ang_Vel_max'].min()
humerusmin = wakefb['Pitching_Humerus_Ang_Vel_max'].min()
handmin = wakefb['Pitching_Hand_Ang_Vel_max'].min()

print("Pelvis angluar velocity min: ", pelvismin, " and max: ", pelvismax)
print("Thorax angluar velocity min: ", thoraxmin, " and max: ", thoraxmax)
print("Pitching humerus angluar velocity min: ", humerusmin, " and max: ", humerusmax)
print("Pitching hand angluar velocity min: ", handmin, " and max: ", handmax)
# Out:
# Pelvis angluar velocity min:  468.050781  and max:  967.925354
# Thorax angluar velocity min:  868.682251  and max:  1462.364746
# Pitching humerus angluar velocity min:  3857.48999  and max:  8411.916016
# Pitching hand angluar velocity min:  2271.743896  and max:  18931.30273

# %%
# Linear model plot of kinematic sequences points
# Pelvis angular velocity VS Thorax angular velocity

sequence = sns.lmplot(x='Pelvis_Ang_Vel_max', y='Thorax_Ang_Vel_max', data=wakefb, hue='Pitcher')
sequence.set(xlim=(400, 1000))
sequence.set(ylim=(800, 1500))
sequence.set(title="Linear Model - Pelvis to Trunk Angular Velocity")

# %%
# Scatter plot of kinematic sequences points 1 & 2
# Pelvis angular velocity VS Thorax angular velocity

ksequence1 = sns.scatterplot(x='Pelvis_Ang_Vel_max', y='Thorax_Ang_Vel_max', data=wakefb, hue='Pitcher')
ksequence1.set(xlim=(400, 1000))
ksequence1.set(ylim=(800, 1500))
ksequence1.set(title="Pelvis to Trunk Energy Transfer - Angular Velocity")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# Plot K-vest relative speed gains!!!

# %%
# Scatter plot of kinematic sequences points 2 & 3
# Thorax angular velocity VS Pitching humerus angular velocity

ksequence2 = sns.scatterplot(x='Thorax_Ang_Vel_max', y='Pitching_Humerus_Ang_Vel_max', data=wakefb, hue='Pitcher')
ksequence2.set(xlim=(800, 1500))
ksequence2.set(ylim=(3000, 9000))
ksequence2.set(title="Trunk to Humerus Energy Transfer - Angular Velocity")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# Plot K-vest relative speed gains!!!

# %%
# Scatter plot of kinematic sequences points 3 & 4
# Pitching humerus angular velocity VS Pitching hand angular velocity

ksequence3 = sns.scatterplot(x='Pitching_Humerus_Ang_Vel_max', y='Pitching_Hand_Ang_Vel_max', data=wakefb, hue='Pitcher')
ksequence3.set(xlim=(3000, 9000))
ksequence3.set(ylim=(2000, 20000))
ksequence3.set(title="Humerus to Hand Energy Transfer - Angular Velocity")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# Plot K-vest relative speed gains!!!

# %%
# Look into elbow extension velocity instead of hand angular velocity

elbowext = sns.scatterplot(x='Pitching_Humerus_Ang_Vel_max', y='Pitching_Elbow_Angle@Max_Shoulder_RotX', data=wakefb, hue='Pitcher')
elbowext.set(xlim=(3000, 9000))
elbowext.set(ylim=(40, 140))
elbowext.set(title="Humerus to Elbow Energy Transfer")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
# Plot mph per unit of force/torque in elbow and shoulder
# Max_Elbow_Flex_Torque
# Max_Elbow_Valgus_Torque
# Max_Elbow_Varus_Torque
# Max_Shoulder_Abd_Torque
# Max_Shoulder_Dist_Force
# Max_Shoulder_Hor_Abd_Torque
# Max_Shoulder_Hor_Add_Torque
# Max_Shoulder_IntRot_Torque
# Max_Elbow_Force
# Elbow_Torque@Max_Shoulder_Rot
# Elbow_Torque@Release
